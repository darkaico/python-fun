# %%
prices_data = {
    "00-01": {
        "date": "29-10-2022",
        "hour": "00-01",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 132.75,
        "units": "€/Mwh"
    },
    "01-02": {
        "date": "29-10-2022",
        "hour": "01-02",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 130.86,
        "units": "€/Mwh"
    },
    "02-03": {
        "date": "29-10-2022",
        "hour": "02-03",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 128.8,
        "units": "€/Mwh"
    },
    "03-04": {
        "date": "29-10-2022",
        "hour": "03-04",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 126.02,
        "units": "€/Mwh"
    },
    "04-05": {
        "date": "29-10-2022",
        "hour": "04-05",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 125.12,
        "units": "€/Mwh"
    },
    "05-06": {
        "date": "29-10-2022",
        "hour": "05-06",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 124.58,
        "units": "€/Mwh"
    },
    "06-07": {
        "date": "29-10-2022",
        "hour": "06-07",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 130.47,
        "units": "€/Mwh"
    },
    "07-08": {
        "date": "29-10-2022",
        "hour": "07-08",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 143.25,
        "units": "€/Mwh"
    },
    "08-09": {
        "date": "29-10-2022",
        "hour": "08-09",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 156.01,
        "units": "€/Mwh"
    },
    "09-10": {
        "date": "29-10-2022",
        "hour": "09-10",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 147.63,
        "units": "€/Mwh"
    },
    "10-11": {
        "date": "29-10-2022",
        "hour": "10-11",
        "is-cheap": False,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 131.55,
        "units": "€/Mwh"
    },
    "11-12": {
        "date": "29-10-2022",
        "hour": "11-12",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 121.95,
        "units": "€/Mwh"
    },
    "12-13": {
        "date": "29-10-2022",
        "hour": "12-13",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 118.04,
        "units": "€/Mwh"
    },
    "13-14": {
        "date": "29-10-2022",
        "hour": "13-14",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 113.61,
        "units": "€/Mwh"
    },
    "14-15": {
        "date": "29-10-2022",
        "hour": "14-15",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 118.01,
        "units": "€/Mwh"
    },
    "15-16": {
        "date": "29-10-2022",
        "hour": "15-16",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 120.5,
        "units": "€/Mwh"
    },
    "16-17": {
        "date": "29-10-2022",
        "hour": "16-17",
        "is-cheap": True,
        "is-under-avg": True,
        "market": "PVPC",
        "price": 121.2,
        "units": "€/Mwh"
    },
    "17-18": {
        "date": "29-10-2022",
        "hour": "17-18",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 144.62,
        "units": "€/Mwh"
    },
    "18-19": {
        "date": "29-10-2022",
        "hour": "18-19",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 174.78,
        "units": "€/Mwh"
    },
    "19-20": {
        "date": "29-10-2022",
        "hour": "19-20",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 179.1,
        "units": "€/Mwh"
    },
    "20-21": {
        "date": "29-10-2022",
        "hour": "20-21",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 171.71,
        "units": "€/Mwh"
    },
    "21-22": {
        "date": "29-10-2022",
        "hour": "21-22",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 172.21,
        "units": "€/Mwh"
    },
    "22-23": {
        "date": "29-10-2022",
        "hour": "22-23",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 166.22,
        "units": "€/Mwh"
    },
    "23-24": {
        "date": "29-10-2022",
        "hour": "23-24",
        "is-cheap": False,
        "is-under-avg": False,
        "market": "PVPC",
        "price": 161.01,
        "units": "€/Mwh"
    }
}

# %%
import matplotlib.pyplot as plt
import numpy as np

hours = []
labels = []
prices = []
i = 0
for price_label in prices_data:
    hours.append(i)
    i += 1
    labels.append(price_label.split('-')[0])
    prices.append(prices_data[price_label]['price'])


x = np.array(hours)
y = np.array(prices)

plt.xticks(x, labels)
plt.bar(x, y)

plt.xlabel("Hora")
plt.ylabel("€ / Mwh")

plt.show()
